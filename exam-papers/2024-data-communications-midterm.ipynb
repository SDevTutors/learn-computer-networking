# %% [markdown]
# # Data Communications - 2024 - Midterm - Sample Paper

# %% [markdown]
# Now that you know how to represent a signal in Python, do the following;
#
# 1. Plot a 4.5 Hz sine wave with a phase of 180 degrees
# 2. Plot a 1kHz sine wave with an RMS amplitude of 3±V
# 3. Plot a 1MHz signal sampled at 8MHz

# %%
from numpy import arange, pi, sin, linspace
import matplotlib.pyplot as plt
import math

time = linspace(0, 1e-3, 1_000)

amplitude = 4.242
frequency = 1_000
phase = 0

sin_wave_values = amplitude * sin(2 * pi * frequency * time + phase)

plt.plot(time, sin_wave_values)
plt.title("Sine wave")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (Volts)")
plt.grid(True, which="both")
plt.axhline(y=0, color="k")
plt.show()

# %% [markdown]
# ## Question 1 [Total Marks: 25]

# %% [markdown]
# ### Question 1.A

# %% [markdown]
# A sinusoidal signal $x(t)$ is described by the equation:
#
# $$x(t) = -4.25 \sin(2750t + 1.6)$$
#
# 1. What is the frequency of the signal?
# 2. Sketch the signal for $0 \leq t \leq 3$ msec.
# 3. If the signal was delayed by 0.5 msec, write out the new equation for the signal.
#
# **[8 Marks]**

# %% [markdown]
# #### Answer 1.A.1

# %% [markdown]
# The frequency of the signal is the coefficient of $t$ in the argument of the sine function. Therefore, the frequency of the signal is $f = \frac{2750}{2\pi} \approx 437.5$ Hz.

# %% [markdown]
# #### Answer 1.A.2

# %%
from numpy import linspace, pi, sin
import matplotlib.pyplot as plt

# Define the parameters
amplitude = -4.25
frequency = 2_750 / (2 * pi)  # Convert angular frequency to Hz
phase_shift = 1.6
time = linspace(0, 3e-3, 1_000)  # Time vector from 0 to 3 milliseconds

# Define the signal
x_t = amplitude * sin(2+750 * time + phase_shift)

# Plot the signal
plt.figure()
plt.plot(time * 1e3, x_t)  # Convert time to milliseconds for plotting
plt.title("Sinusoidal Signal $x(t) = -4.25 \sin(2750t + 1.6)$")
plt.xlabel("Time (ms)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.ylim(-5, 5)
plt.xlim(0, 3)
plt.show()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_39724\3502610643.py:16: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("Sinusoidal Signal $x(t) = -4.25 \sin(2750t + 1.6)$")

# %% [markdown]
# #### Answer 1.A.3
# If the signal was delayed by 0.5 msec, write out the new equation for the signal.
#
# To Add a delay to the signal, we need to subtract the delay from the phase term of the signal ($1.6$). Therefore, the new equation for the signal is:
#
# $x(t) = -4.25 \sin(2750(t) + 1.6 - 0.5) =$
# $x(t) = -4.25 \sin(2750(t) + 1.1)$
#
# $$\boxed{ x(t) = -4.25 \sin(2750(t) + 1.1) }$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
amplitude = -4.25
frequency = 2750 / (2 * np.pi)  # Convert angular frequency to Hz
phase_shift = 1.6
time = np.linspace(0, 3e-3, 1000)  # Time vector from 0 to 3 milliseconds

# Define the original signal
x_t = amplitude * np.sin(2750 * time + phase_shift)

# Define the new signal with the time shift
x_t_shifted = amplitude * np.sin(2750 * (time - 0.5e-3) + phase_shift)

# Plot the signals
plt.figure()
plt.plot(time * 1e3, x_t, label='$x(t) = -4.25 \sin(2750t + 1.6)$')
plt.plot(time * 1e3, x_t_shifted, label='$x(t) = -4.25 \sin(2750(t - 0.5) + 1.6)$', linestyle='--')
plt.title('Sinusoidal Signals')
plt.xlabel('Time (ms)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.ylim(-5, 5)
plt.xlim(0, 3)
plt.legend()
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_31668\2223985.py:18: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(time * 1e3, x_t, label='$x(t) = -4.25 \sin(2750t + 1.6)$')
# C:\Users\user\AppData\Local\Temp\ipykernel_31668\2223985.py:19: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(time * 1e3, x_t_shifted, label='$x(t) = -4.25 \sin(2750(t - 0.5) + 1.6)$', linestyle='--')

# %% [markdown]
# ---
#
# ### Question 1.B
#
# Signals can be viewed in the time domain or the frequency domain.
#
# #### Question 1.B.1
#
# Explain the concepts of time domain and frequency domain.
#
# #### Answer 1.B.1
#
# **Time Domain vs. Frequency Domain:**
#
# **Time Domain:**
# The time domain represents a signal as a function of time. When we analyze a signal in the time domain, we observe how the signal's amplitude or value changes over time. This is the most intuitive representation of a signal, often visualized as a waveform where the x-axis represents time, and the y-axis represents the amplitude (or value) of the signal.
#
# **Key Characteristics:**
# - Focuses on the behavior of the signal over time.
# - Amplitude changes are tracked as time progresses.
# - Commonly used for signals like audio, video, and electrical waveforms.
#
# **Example:**
# An audio signal might be represented as a continuous waveform showing how the sound intensity changes from one moment to the next over time.
#
# **Frequency Domain:**
# The frequency domain represents a signal in terms of its frequency components rather than time. When analyzing a signal in the frequency domain, we look at how much of the signal's energy is present at each frequency. This representation is achieved through mathematical transformations like the **Fourier Transform**, which decomposes the signal into its constituent sinusoidal frequencies.
#
# **Key Characteristics:**
# - Focuses on the distribution of the signal's energy across different frequencies.
# - Shows which frequencies are present in the signal and how strong they are.
# - Useful for understanding periodicity, filtering, and analyzing bandwidth.
#
# - **Example:**
#   The same audio signal, when transformed into the frequency domain, would show the dominant frequencies (such as bass, midrange, and treble) and their intensities, instead of how the signal changes over time.
#
# **Comparison:**
# - **Time Domain:** Emphasizes the progression and changes of the signal as time moves forward.
# - **Frequency Domain:** Highlights the underlying frequency components of the signal, providing insight into periodicities and spectral content.
#
# Both domains provide complementary views of the same signal, and one can often switch between them using mathematical tools like the Fourier Transform (for time to frequency) or the Inverse Fourier Transform (for frequency to time).
#
# #### Question 1.B.2 (6 Marks)
#
# Explain how a frequency domain view could be generated from a time series representation of a signal.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Define the parameters
amplitude = 1.0
frequency = 1.0  # Frequency in Hz
sampling_rate = 100.0  # Sampling rate in Hz
duration = 2.0  # Duration in seconds

# Generate the time vector
t = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

# Generate the signal in the time domain
x_t = amplitude * np.sin(2 * np.pi * frequency * t)

# Compute the Fourier Transform to get the frequency domain representation
x_f = fft(x_t)
frequencies = fftfreq(len(t), 1 / sampling_rate)

# Plot the signal in the time domain
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(t, x_t)
plt.title('Time Domain')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

# Plot the signal in the frequency domain
plt.subplot(2, 1, 2)
plt.plot(frequencies[:len(frequencies)//2], np.abs(x_f)[:len(frequencies)//2])
plt.title('Frequency Domain')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 1(c) (5 Marks)
#
# Explain the difference between an analogue and a digital signal. Give two examples of each.
#
# ### Answer 1.C
#
# Continues signals are represented by analogue signals, and discrete signals are represented by digital signals. The difference between analogue and digital signals lies in their representation and transmission methods.

# %% [markdown]
# ### Question 1.D (5 Marks)

# %% [markdown]
# Sampling an analogue signal to convert it to a digital signal sometimes results in aliasing. Explain how aliasing occurs and how it can be prevented.

# %% [markdown]
# ### Answer 1.D

# %% [markdown]
# Aliasing occurs when the sampling rate is too low to capture the frequency content of the signal. This results in the signal being reconstructed with a lower frequency than the original signal. Aliasing can be prevented by using a sampling rate that is at least twice the highest frequency component of the signal. This is known as the Nyquist-Shannon sampling theorem.

# %% [markdown]
# ## QUESTION 2 (25 Marks)

# %% [markdown]
# ### Question 2.A (6 Marks)

# %% [markdown]
# Outline 3 causes of signal degradation in a data communications system.

# %% [markdown]
# ### Answer 2.A

# %% [markdown]
# 1. **Attenuation:**
#    - Signal attenuation refers to the loss of signal strength as it travels through a medium or across a network. This can be caused by factors like distance, interference, or the medium's properties.
#    - Attenuation can lead to a decrease in signal quality, making it harder to distinguish the signal from noise and potentially causing errors in data transmission.
# 2. **Noise:**
#    - Noise is any unwanted or random interference that distorts the original signal. It can be introduced by external sources, equipment imperfections, or environmental factors.
#    - Noise can corrupt the signal, making it harder to interpret and leading to errors in data reception.
# 3. **Interference:**
#     - Interference occurs when external signals or electromagnetic fields disrupt the transmission of the intended signal. This can be caused by other devices, crosstalk, or electromagnetic radiation.
#     - Interference can distort the signal, introduce errors, and reduce the overall quality of data communication.

# %% [markdown]
# ---
#
# ### Question 2(b)
#
# Outline 3 reasons why optical fibre is better than copper for high-speed long-distance data communications.
#
# **[6 Marks]**
#
# ---

# %% [markdown]
# ### Answer 2(b)
#
# 1. **Higher Bandwidth:**
#    - Optical fibers have a much higher bandwidth compared to copper cables. This allows them to carry more data over longer distances without signal degradation.
#    - The higher bandwidth of optical fibers enables faster data transmission rates, making them ideal for high-speed communication applications.
# 2. **Lower Attenuation:**
#    - Optical fibers experience lower signal attenuation compared to copper cables. This means that the signal can travel longer distances without significant loss in strength.
#    - Lower attenuation reduces the need for signal amplification or regeneration, making optical fibers more efficient for long-distance communication.
# 3. **Immunity to Electromagnetic Interference:**
#    - Optical fibers are immune to electromagnetic interference, unlike copper cables that can be affected by external electromagnetic fields or crosstalk.
#    - This immunity makes optical fibers more reliable for data transmission in environments with high electromagnetic interference, such as industrial settings or areas with high electrical activity
# 4. **Security:**
#    - Optical fibers are more secure than copper cables because they do not radiate electromagnetic signals that can be intercepted or tapped.
#    - This makes optical fibers ideal for transmitting sensitive or confidential data over long distances without the risk of eavesdropping or data interception.

# %% [markdown]
# ### Question 2.C
#
# Decibels (dB) are often encountered as a unit of measure in data communications. There are different types of dB including dBm, dBi, dBc, and dBd.
#
# #### Question 2.C.1
#
# Give 2 reasons why it is often advantageous to use decibels.
#
# #### Answer 2.C.1
#
# 1. **Logarithmic Scale:**
#    - Decibels provide a logarithmic scale for representing signal power, voltage, or intensity. This allows a wide range of values to be expressed in a compact and manageable form.
#    - The logarithmic nature of decibels makes it easier to compare and analyze signal levels that span several orders of magnitude.
# 2. **Relative Measurements:**
#    - Decibels allow for relative measurements by comparing a signal to a reference value. This makes it easier to quantify changes in signal strength or power relative to a known baseline.
#    - Relative measurements in decibels are useful for assessing signal gain, loss, or attenuation in communication systems.

# %% [markdown]
# #### Question 2.C.2

# %% [markdown]
# What is the difference between dB and dBm? When would you use each?
#
# #### Answer 2.C.2
#
# **Difference between dB and dBm:**
#
# - **dB (Decibel):**
#   - Decibel is a unit of measurement that represents the ratio of two values on a logarithmic scale. It is dimensionless and is used to express the relative difference between two power levels, voltages, or intensities.
#   - dB is a relative measurement that compares a signal to a reference value, often expressed as a ratio or difference in power levels.
# - **dBm (Decibel-milliwatt):**
#   - dBm is a unit of measurement that represents power levels relative to 1 milliwatt (mW). It is an absolute measurement of power and is commonly used in telecommunications to express signal strength.
#   - dBm provides an absolute reference point for signal power, with 0 dBm equivalent to 1 milliwatt of power.

# %% [markdown]
# **[7 Marks]**
#
# ---

# %% [markdown]
# ### Question 2.D (6 Marks)

# %% [markdown]
# A data transmission system transmitter launches +22 dBm of power into a cable. The cable is 15 km in length and has a loss of 0.8 dB per kilometre. What is the received power level in watts at the receiver?

# %% [markdown]
# ### Answer 2.D
#
# To calculate the received power at the receiver in watts, we can follow these steps:
#
# **Step 1: Determine the total loss in dB**:
#
# - The cable loss is 0.8 dB per kilometer.
# - The cable is 15 km long.
#
# The total loss $L_{\text{total}}$ in dB is given by:
#
# $$L_{\text{total}} = \alpha \times d$$
#
# Where:
# - $L_{\text{total}}$ is the total loss in dB,
# - $\alpha$ is the attenuation (i.e *loss*) per unit distance (in dB per kilometer, for example) = 0.8 dB/km,
# - $d$ is the total length of the transmission medium (in kilometers, meters, etc., depending on the units of $\alpha$) = 15.
#
#    $L_{\text{total}} = \alpha \times d$
#
#    $L_{\text{total}} = 0.8 \, \text{dB/km} \times 15 \, \text{km} = 12 \, \text{dB}$
#
# **Step 2: Calculate the received power in dBm**:
#
# - The transmitter launches +22 dBm of power.
# - The cable introduces a loss of 12 dB.
#
# The received power $P_{\text{received}}$ in dBm is:
#
# $P_{\text{received}} = P_{\text{transmitted}} - L_{\text{total}}$
#
# $P_{\text{received}} = 22 \, \text{dBm} - 12 \, \text{dB} = 10 \, \text{dBm}$
#
# **Step 3: Convert the received power from dBm to watts**:
#
# To convert power from dBm to watts, use the following formula:
#
# Note: $\times 10^{-3}$ is used to convert milliwatts to watts.
#
# $$P_{\text{watts}} = 10^{(\frac{P_{\text{dBm}}}{10})} \times 10^{-3}$$
#
# Substituting the value of $P_{\text{dBm}} = 10$:
#
# $P_{\text{watts}} = 10^{(\frac{10}{10})} \times 10^{-3} = 10^1 \times 10^{-3} = 10 \times 10^{-3} = 0.01 \, \text{W}$
#
# ### **Final Answer:**
# The received power at the receiver is **0.01 watts** or **10 milliwatts**.

# %% [markdown]
# ## Question 3 [TOTAL MARKS: 25]

# %% [markdown]
# ### Question 3.A (6 Marks)

# %% [markdown]
# Outline 3 advantages of using modulation in a data communication system.

# %% [markdown]
# ### Answer 3.A

# %% [markdown]
# Here are three key advantages of using modulation in a data communication system:
#
# 1. **Efficient Use of Bandwidth:**
#    - **Advantage:** Modulation allows multiple signals to be transmitted over a shared medium by shifting each signal to a different frequency range. This is commonly referred to as **frequency division multiplexing (FDM)**.
#    - **Benefit:** It enables the simultaneous transmission of multiple data streams, maximizing the available bandwidth and improving the efficiency of the communication system.
# 2. **Improved Signal Transmission Over Long Distances:**
#    - **Advantage:** Modulation, particularly at higher frequencies, helps in transmitting signals over longer distances with less degradation. Low-frequency signals (such as baseband signals) suffer more from attenuation and interference, while modulated signals in higher frequency bands (such as radio waves) are more resilient.
#    - **Benefit:** It extends the transmission range and improves signal clarity, making communication over long distances more reliable.
# 3. **Reduced Interference and Noise:**
#    - **Advantage:** By shifting the frequency of the baseband signal to a higher frequency range, modulation can avoid the effects of noise and interference that are typically concentrated at lower frequencies. Additionally, modulation schemes such as frequency modulation (FM) and phase modulation (PM) are inherently more resistant to certain types of noise.
#    - **Benefit:** This results in better signal quality, with less distortion and fewer errors during transmission.
#
# In summary, modulation improves bandwidth efficiency, enhances long-distance communication, and reduces the impact of noise and interference in data communication systems.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3.B (6 Marks)

# %% [markdown]
# Digital modulation systems are often less susceptible to noise than analogue modulation systems. Explain.

# %% [markdown]
# ### Answer 3.B

# %% [markdown]
# Digital modulation systems are less susceptible to noise compared to analog modulation systems for several reasons:
#
# 1. **Discrete Signal Levels and Threshold Detection**
# Digital signals consist of discrete levels, often just two (representing binary 0s and 1s), which makes it easier for a receiver to distinguish between the signal and noise. Small amounts of noise may slightly distort the signal, but as long as the distortion doesn't push the signal past a certain threshold, the receiver can still correctly interpret the data.
#
# 2. **Error Detection and Correction Techniques**
# Digital modulation schemes often incorporate error detection and correction techniques, such as parity checks or more sophisticated algorithms like forward error correction. These techniques help identify and correct errors introduced by noise, further reducing its impact on communication reliability.
#
# 3. **Noise-Resilient Coding and Interleaving**
# Digital modulation can utilize techniques such as coding and interleaving, which spread the data across multiple symbols or time slots. This makes the system more robust against noise and interference, as the effect of noise on any one symbol is mitigated by the ability to reconstruct the signal using the information spread across the system.
#
# In summary, the discrete nature of digital signals, combined with error correction techniques and noise-resilient encoding methods, makes digital modulation systems inherently more resistant to noise than their analog counterparts.

# %% [markdown]
# ### Question 3.C (7 Marks)
#
# A data communications receiver has an SNR of 35 dB and a bandwidth of 1.5 MHz. How many levels should it use to get the maximum bitrate? Suggest a suitable modulation scheme to achieve the maximum bitrate.
#
# ### Answer 3.C
#
# To determine the number of levels required to achieve the maximum bitrate, we can use the Shannon-Hartley theorem, which relates the maximum achievable data rate to the signal-to-noise ratio (SNR) and the bandwidth of the channel.
#
# The Shannon-Hartley theorem is given by:
#
# $$C = B \log_2(1 + \text{SNR}_{\text{linear}})$$
#
# Where:
#
# - $C$ is the channel capacity (maximum achievable data rate),
# - $B$ is the bandwidth of the channel,
# - $\text{SNR}_{\text{linear}}$ is the signal-to-noise ratio in linear scale in Hertz (H).
#
# Given:
# - $B = 1.5MHz = 1.5 \times 10^6$ Hz.
# - $\text{SNR} = 35$ dB,
#
# First, we need to convert the SNR from dB to a linear scale:
#
# $\text{SNR}_{\text{linear}} = 10^{\left(\frac{\text{SNR}}{10}\right)} = 10^{\left(\frac{35}{10}\right)} = 10^{3.5} \approx 3,162.3$
#
# Substitute the values into the Shannon-Hartley theorem:
#
# $B \log_2(1 + \text{SNR}_{\text{linear}}) = C$
# $(1.5 \times 10^6) \log_2(1 + 3162.3) =$
# $(1.5 \times 10^6) \log_2(3163.3) \approx$
# $(1.5 \times 10^6) \times 11.62 \approx$
# $17.43 \times 10^6 \text{ bps} = $
# $17.43 \text{ Mbps}$
#
#
# **Modulation Scheme and Levels:**
# To determine the number of levels in a digital modulation scheme (such as Quadrature Amplitude Modulation, QAM), the formula relating the number of levels $M$ to the bitrate $R$, bandwidth $B$, and bits per symbol $\log_2(M)$ is:
#
# $R = B \cdot \log_2(M)$
#
# Since we have already calculated that the maximum bitrate is 17.43 Mbps, and the bandwidth is 1.5 MHz, we can determine the required number of levels $M$ by solving for $\log_2(M)$:
#
# *Keep M as an expression of $2^n$ where n is the number of bits per symbol*
#
# Let
#
# - $R = 17.43 \times 10^6$ bps,
# - $B = 1.5MHz = 1.5 \times 10^6$ Hz.
#
# $R = B \cdot \log_2(M)$
#
# $17.43 \times 10^6 = 1.5 \times 10^6 \times \log_2(M)$
# $17.43 = 1.5 \times \log_2(M)$
# $\dfrac{17.43}{1.5} = \log_2(M)$
# $\log_2(M) = 11.62$
#
# Applying Logarithmic properties:
#
# $Log_a(b) = c \implies a^c = b$
#
# Thus, the required number of levels is:
#
# $\log_2(M) = 11.62 \implies M = 2^{11.62}$
#
# You cannot have a fractional number of levels, so you would round up to the nearest integer.
#
# $\therefore M \approx 2^{12} = 4,096$
#
# The closest suitable modulation scheme would be **4096-QAM** (which uses 12 bits per symbol, as $\log_2(4096) = 12$).
#
# **Final Answer:**
#
# To achieve the maximum bitrate with an SNR of 35 dB and a bandwidth of 1.5 MHz, the receiver should use a modulation scheme that supports approximately **17.43 Mbps**. A suitable modulation scheme would be **4096-QAM**, which uses **12 bits per symbol** and supports a high data rate.

# %% [markdown]
# ### Question 3.D (6 Marks)

# %% [markdown]
# Draw the constellation diagram for the following modulation schemes:
#
# *Ensure that the axes of all diagrams are labelled to show signal amplitudes*

# %% [markdown]
# #### Question 3.D.1

# %% [markdown]
# QPSK with a peak amplitude value of 1V and phases of 0 degrees, 90 degrees, 180 degrees, and 270 degrees.

# %% [markdown]
# #### Answer 3.D.1
#
# **Steps to Calculate QPSK Constellation Points**:
#
# 1. **Understand the Parameters**:
#    - **Amplitude**: 1V.
#    - **Phases**: 0°, 90°, 180°, and 270°.
#
# 2. **Convert Phases to Radians**:
#    - 0° = 0 radians
#    - 90° = $\pi/2$ radians
#    - 180° = $\pi$ radians
#    - 270° = $3\pi/2$ radians
#
# 3. **Calculate the Points**:
#    - Use the formula for converting polar coordinates (amplitude and phase) to Cartesian coordinates (I and Q):
#      $$
#      I = A \cos(\theta)
#      $$
#      $$
#      Q = A \sin(\theta)
#      $$
#    - Where $A$ is the amplitude and $\theta$ is the phase.
#
# 4. **Calculate Points for Each Phase**:
#    - For $\theta = 0^\circ$ (0 radians):
#      $$
#      I = 1 \cos(0) = 1 \cdot 1 = 1
#      $$
#      $$
#      Q = 1 \sin(0) = 1 \cdot 0 = 0
#      $$
#      Point: $(1, 0)$
#    - For $\theta = 90^\circ$ ($\pi/2$ radians):
#      $$
#      I = 1 \cos(\pi/2) = 1 \cdot 0 = 0
#      $$
#      $$
#      Q = 1 \sin(\pi/2) = 1 \cdot 1 = 1
#      $$
#      Point: $(0, 1)$
#    - For $\theta = 180^\circ$ ($\pi$ radians):
#      $$
#      I = 1 \cos(\pi) = 1 \cdot -1 = -1
#      $$
#      $$
#      Q = 1 \sin(\pi) = 1 \cdot 0 = 0
#      $$
#      Point: $(-1, 0)$
#    - For $\theta = 270^\circ$ ($3\pi/2$ radians):
#      $$
#      I = 1 \cos(3\pi/2) = 1 \cdot 0 = 0
#      $$
#      $$
#      Q = 1 \sin(3\pi/2) = 1 \cdot -1 = -1
#      $$
#      Point: $(0, -1)$
#
# ### Summary of Points:
# - $(1, 0)$
# - $(0, 1)$
# - $(-1, 0)$
# - $(0, -1)$
#
# These are the points you would plot on the I-Q plane to draw the QPSK constellation diagram by hand.

# %% [markdown]
# QPSK with a peak amplitude value of 1V and phases of 0 degrees, 90 degrees, 180 degrees, and 270 degrees.

# %%
import numpy as np
import matplotlib.pyplot as plt

# QPSK parameters
amplitude_qpsk = 1
phases_qpsk = [0, np.pi/2, np.pi, 3*np.pi/2]
labels_qpsk = ['0°', '90°', '180°', '270°']

# Calculate QPSK constellation points
qpsk_points = [amplitude_qpsk * np.exp(1j * phase) for phase in phases_qpsk]

# Plot QPSK constellation diagram
plt.figure(figsize=(6, 6))
plt.scatter(np.real(qpsk_points), np.imag(qpsk_points), color='blue')
for point, label in zip(qpsk_points, labels_qpsk):
    plt.text(np.real(point), np.imag(point), f'{label}\n({np.real(point):.1f}, {np.imag(point):.1f})', fontsize=12, ha='center')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('QPSK Constellation Diagram')
plt.xlabel('In-phase (I)')
plt.ylabel('Quadrature (Q)')
plt.grid(True)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# #### Question 3.D.2
#
# 8-QAM with 2 different amplitude values of 2V and 4V respectively and four different phases of $\pi/4$, $3\pi/4$, $5\pi/4$, and $7\pi/4$.

# %% [markdown]
# #### Answer 3.D.2

# %% [markdown]
# ### Steps to Calculate 8-QAM Constellation Points
#
# 1. **Understand the Parameters**:
#    - **Amplitudes** $A$ : 2V and 4V.
#    - **Phases** $\theta$: $\pi/4$, $3\pi/4$, $5\pi/4$, and $7\pi/4$.
#
# 2. **Convert Phases to Degrees**:
#    - $\pi/4$ = 45°
#    - $3\pi/4$ = 135°
#    - $5\pi/4$ = 225°
#    - $7\pi/4$ = 315°
#
# 3. **Calculate the Points**:
#    - Use the formula for converting polar coordinates (amplitude and phase) to Cartesian coordinates (I and Q):
#      $$
#      I = A \cos(\theta)
#      $$
#      $$
#      Q = A \sin(\theta)
#      $$
#    - Where $A$ is the amplitude and $\theta$ is the phase.
#
# 4. **Calculate Points for Each Amplitude and Phase**:
#    - **Amplitude = 2V**:
#      - For $\theta = 45^\circ$:
#        $$I = 2 \cos(45^\circ) = 2 \cdot \frac{\sqrt{2}}{2} = \sqrt{2} \approx 1.41$$
#        $$
#        Q = 2 \sin(45^\circ) = 2 \cdot \frac{\sqrt{2}}{2} = \sqrt{2} \approx 1.41
#        $$
#        Point: $(1.41, 1.41)$
#      - For $\theta = 135^\circ$:
#        $$
#        I = 2 \cos(135^\circ) = 2 \cdot -\frac{\sqrt{2}}{2} = -\sqrt{2} \approx -1.41
#        $$
#        $$
#        Q = 2 \sin(135^\circ) = 2 \cdot \frac{\sqrt{2}}{2} = \sqrt{2} \approx 1.41
#        $$
#        Point: $(-1.41, 1.41)$
#      - For $\theta = 225^\circ$:
#        $$
#        I = 2 \cos(225^\circ) = 2 \cdot -\frac{\sqrt{2}}{2} = -\sqrt{2} \approx -1.41
#        $$
#        $$
#        Q = 2 \sin(225^\circ) = 2 \cdot -\frac{\sqrt{2}}{2} = -\sqrt{2} \approx -1.41
#        $$
#        Point: $(-1.41, -1.41)$
#      - For $\theta = 315^\circ$:
#        $$
#        I = 2 \cos(315^\circ) = 2 \cdot \frac{\sqrt{2}}{2} = \sqrt{2} \approx 1.41
#        $$
#        $$
#        Q = 2 \sin(315^\circ) = 2 \cdot -\frac{\sqrt{2}}{2} = -\sqrt{2} \approx -1.41
#        $$
#        Point: $(1.41, -1.41)$
#
#    - **Amplitude = 4V**:
#      - For $\theta = 45^\circ$:
#        $$
#        I = 4 \cos(45^\circ) = 4 \cdot \frac{\sqrt{2}}{2} = 2\sqrt{2} \approx 2.83
#        $$
#        $$
#        Q = 4 \sin(45^\circ) = 4 \cdot \frac{\sqrt{2}}{2} = 2\sqrt{2} \approx 2.83
#        $$
#        Point: $(2.83, 2.83)$
#      - For $\theta = 135^\circ$:
#        $$
#        I = 4 \cos(135^\circ) = 4 \cdot -\frac{\sqrt{2}}{2} = -2\sqrt{2} \approx -2.83
#        $$
#        $$
#        Q = 4 \sin(135^\circ) = 4 \cdot \frac{\sqrt{2}}{2} = 2\sqrt{2} \approx 2.83
#        $$
#        Point: $(-2.83, 2.83)$
#      - For $\theta = 225^\circ$:
#        $$
#        I = 4 \cos(225^\circ) = 4 \cdot -\frac{\sqrt{2}}{2} = -2\sqrt{2} \approx -2.83
#        $$
#        $$
#        Q = 4 \sin(225^\circ) = 4 \cdot -\frac{\sqrt{2}}{2} = -2\sqrt{2} \approx -2.83
#        $$
#        Point: $(-2.83, -2.83)$
#      - For $\theta = 315^\circ$:
#        $$
#        I = 4 \cos(315^\circ) = 4 \cdot \frac{\sqrt{2}}{2} = 2\sqrt{2} \approx 2.83
#        $$
#        $$
#        Q = 4 \sin(315^\circ) = 4 \cdot -\frac{\sqrt{2}}{2} = -2\sqrt{2} \approx -2.83
#        $$
#        Point: $(2.83, -2.83)$
#
# ### Summary of Points:
# - **Amplitude = 2V**:
#   - $(1.41, 1.41)$
#   - $(-1.41, 1.41)$
#   - $(-1.41, -1.41)$
#   - $(1.41, -1.41)$
#
# - **Amplitude = 4V**:
#   - $(2.83, 2.83)$
#   - $(-2.83, 2.83)$
#   - $(-2.83, -2.83)$
#   - $(2.83, -2.83)$
#
# These are the points you would plot on the I-Q plane to draw the 8-QAM constellation diagram by hand.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 8-QAM parameters
amplitudes_8qam = [2, 4]
phases_8qam = [np.pi/4, 3*np.pi/4, 5*np.pi/4, 7*np.pi/4]
labels_8qam = ['45°', '135°', '225°', '315°']

# Calculate 8-QAM constellation points
qam_points = [amplitude * np.exp(1j * phase) for amplitude in amplitudes_8qam for phase in phases_8qam]

# Plot 8-QAM constellation diagram
plt.figure(figsize=(6, 6))
plt.scatter(np.real(qam_points), np.imag(qam_points), color='red')
for i, point in enumerate(qam_points):
    label = labels_8qam[i % len(labels_8qam)]
    plt.text(np.real(point), np.imag(point), f'{label}\n({np.real(point):.1f}, {np.imag(point):.1f})', fontsize=12, ha='center')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('8-QAM Constellation Diagram')
plt.xlabel('In-phase (I)')
plt.ylabel('Quadrature (Q)')
plt.grid(True)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ---
#
# ## QUESTION 4
#
# **[TOTAL MARKS: 25]**
#
# ### Question 4.A (9 Marks)
#
# A data transmission scheme is to transmit the following binary data stream:
#
# $$011 \ 0110 \ 1010$$
#
# Assume the last signal level has been positive. Draw the graph of the output signal for the following coding schemes:
#
# #### Question 4.A.1
#
# NRZ-L
#
# #### Answer 4.A.1
#
# #### Question 4.A.2
#
# Differential Manchester
#
# #### Answer 4.A.2
#
# #### Question 4.A.3
#
# AMI
#
# **[9 Marks]**
#
# ---
#
# ### Question 4(b)
#
# Outline two methods to achieve synchronization between transmitter and receiver for line coding schemes.
#
# **[6 Marks]**
#
# ---
#
# ### Question 4(c)
#
# Explain how DC balance is achieved in 8B6T coding.
#
# **[5 Marks]**
#
# ---
#
# ### Question 4(d)
#
# Explain how bit error detection is achieved in 8B6T coding.
#
# **[5 Marks]**
#
# ---
#
# ## Paper Details
#
# 125a50b7
#
# 13-12-2023 - 14:00
#
# MODULE:
#
# PROGRAMME(S):
# LC_KCSYM_KMY
#
# TUS
# Technological University of the Shannon:
# Midlands Midwest
# Ollscoil Teicneolalochta na Sionainne:
# Lár Tire larthar Láir
#
# TECHNOLOGICAL UNIVERSITY OF THE SHANNON: MIDLANDS MIDWEST
#
# WINTER EXAMINATIONS 2023/2024
#
# CONE07001 - Data Communications
#
# Bachelor of Science (Honours) Computer Networks and
# Systems Management
#
# YEAR OF STUDY:
#
# EXAMINER(S):
#
# 3
#
# Ken Oakley
# John Stapleton
#
# (Internal)
# (Internal)
#
# TIME ALLOWED:
#
# INSTRUCTIONS:
#
# 2.5 HOURS
#
# Answer 4 questions. All questions carry equal marks.
#
# A.
#
# Exam Materials to accompany this paper
#
# The use of a maximum of 2 single sided A4 sized pages
# of personal notes is permitted. Notes may include text,
# formulae and diagrams and must be typed in font no
# smaller than 10 point
#
# PLEASE DO NOT TURN OVER THIS PAGE UNTIL YOU ARE INSTRUCTED TO DO SO.
# The use of programmable or text storing calculators is expressly forbidden.
# Please note that where a candidate answers more than the required number of questions, the
# examiner will mark all questions attempted and then select the highest scoring ones.
#
# Requirements for this paper:
#
# 1. Log Tables
# 2. Calculators
#
# CONE07001 - Data Communications
#
# Winter Examinations 2023/2024
#
# Page 1 of
